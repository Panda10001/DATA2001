# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import geoalchemy2

# %%
engine = create_engine("postgresql+psycopg2://postgres:114514@localhost:5432/postgres")
connection = engine.raw_connection()

# %%
df_business = pd.read_csv('/Users/tiansuohaoer/Desktop/DATA/Businesses.csv')

# %%
specific_row = df_business.iloc[1286:1929]
specific_row
# Out:
#      industry_code  industry_name   sa2_code                         sa2_name  \
# 1286             C  Manufacturing  101021007                        Braidwood
# 1287             C  Manufacturing  101021008                          Karabar
# 1288             C  Manufacturing  101021009                       Queanbeyan
# 1289             C  Manufacturing  101021010                Queanbeyan - East
# 1290             C  Manufacturing  101021012  Queanbeyan West - Jerrabomberra
# ...            ...            ...        ...                              ...
# 1924             C  Manufacturing  128021538            Sutherland - Kirrawee
# 1925             C  Manufacturing  128021607                         Engadine
# 1926             C  Manufacturing  128021608             Loftus - Yarrawarrah
# 1927             C  Manufacturing  128021609                 Woronora Heights
# 1928             C  Manufacturing  199999499                Currently Unknown
#
# ...

# %%
specific_row.to_sql(name='business_manufacture', con = engine , if_exists = 'replace', index = 'false')

# %%
import geopandas as gpd

# %%
countries_gdf = gpd.read_file("/Users/tiansuohaoer/Desktop/DATA/SA2_2021_AUST_SHP_GDA2020")

# %%
countries_gdf
# Out:
#      SA2_CODE21                            SA2_NAME21 CHG_FLAG21  CHG_LBL21  \
# 0     101021007                             Braidwood          0  No change
# 1     101021008                               Karabar          0  No change
# 2     101021009                            Queanbeyan          0  No change
# 3     101021010                     Queanbeyan - East          0  No change
# 4     101021012       Queanbeyan West - Jerrabomberra          0  No change
# ...         ...                                   ...        ...        ...
# 2468  901031003                            Jervis Bay          0  No change
# 2469  901041004                        Norfolk Island          0  No change
# 2470  997979799  Migratory - Offshore - Shipping (OT)          0  No change
# 2471  999999499                 No usual address (OT)          0  No change
# 2472  ZZZZZZZZZ                     Outside Australia          1        New
#
# ...

# %%
countries_cleaned = countries_gdf[["SA2_CODE21","SA2_NAME21","AREASQKM21","geometry"]]
countries_cleaned
# Out:
#      SA2_CODE21                            SA2_NAME21  AREASQKM21  \
# 0     101021007                             Braidwood   3418.3525
# 1     101021008                               Karabar      6.9825
# 2     101021009                            Queanbeyan      4.7620
# 3     101021010                     Queanbeyan - East     13.0032
# 4     101021012       Queanbeyan West - Jerrabomberra     13.6748
# ...         ...                                   ...         ...
# 2468  901031003                            Jervis Bay     67.2296
# 2469  901041004                        Norfolk Island     38.6510
# 2470  997979799  Migratory - Offshore - Shipping (OT)         NaN
# 2471  999999499                 No usual address (OT)         NaN
# 2472  ZZZZZZZZZ                     Outside Australia         NaN
#
#                                                geometry
# 0     POLYGON ((149.58 -35.444, 149.58 -35.444, 149....
# 1     POLYGON ((149.22 -35.367, 149.22 -35.367, 149....
# ...

# %%
countries_cleaned["wkt"] = countries_cleaned["geometry"].apply(lambda geom: geom.wkt if geom is not None else None)

countries_cleaned["geom_sql"] = countries_cleaned["wkt"].apply(
    lambda wkt: f"ST_GeomFromText('{wkt}', 4326)" if wkt is not None else None
)

countries_cleaned["geom_sql"]
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /opt/anaconda3/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# 0       ST_GeomFromText('POLYGON ((149.5842384630081 -...
# 1       ST_GeomFromText('POLYGON ((149.2189874391411 -...
# 2       ST_GeomFromText('POLYGON ((149.2132649330965 -...
# ...

# %%
#  Connect to the Postgres database
conn = psycopg2.connect(
    dbname="postgres",
    user="postgres",
    password="114514",
    host="localhost",      # optional, default is localhost
    port="5432"            # optional, default is 5432
)
cur = conn.cursor()

# Loop through the GeoDataFrame and insert each row
for _, row in countries_cleaned.iterrows(): 
    sa2_code = row["SA2_CODE21"]
    name = row["SA2_NAME21"]
    geom_sql = row["geom_sql"]

    # Skip rows with missing geometry
    if geom_sql is None:
        print(f"Skipping row with missing geometry: {name}")
        continue

    # Safe SQL insert using parameter for name, but geom_sql is injected raw
    sql = f"""
    INSERT INTO spatial (sa2_code, name, geom)    
    VALUES (%s,%s, {geom_sql});                   
    """
    cur.execute(sql, (sa2_code , name))         

# Save changes and clean up
conn.commit()
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[54], line 27
#      22     # Safe SQL insert using parameter for name, but geom_sql is injected raw
#      23     sql = f"""
#      24     INSERT INTO spatial (sa2_code, name, geom)
#      25     VALUES (%s,%s, {geom_sql});
#      26     """
# ---> 27     cur.execute(sql, (sa2_code , name))
#      29 # Save changes and clean up
#      30 conn.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "spatial_pkey"
# DETAIL:  Key (sa2_code)=(101021007) already exists.

# %%
countries_cleaned = countries_cleaned.head(2472)

# %%
countries_cleaned

# %%
print(countries_cleaned.crs)

# %%
specific_income = pd.read_csv("/Users/tiansuohaoer/Desktop/DATA/Income.csv", na_values=["np.nan", "np", "NaN"])
specific_income.to_sql(name='income_clean', con=engine, if_exists='replace')

# %%
specific_population = pd.read_csv("/Users/tiansuohaoer/Desktop/DATA/Population.csv")
specific_population = specific_population[(specific_population != 0).all(axis=1)]
specific_population.to_sql(name='population_clean', con=engine, if_exists='replace')

# %%
specific_stops = pd.read_csv("/Users/tiansuohaoer/Desktop/DATA/Stops.txt", na_values=["np.nan", "np", "NaN"])
specific_stops = specific_stops[(specific_stops != 0).all(axis=1)]
specific_stops.to_sql(name='stops_clean', con=engine, if_exists='replace')
# Out:
# /var/folders/xf/z41m1bb94kd50h0qct7r1mxm0000gn/T/ipykernel_13058/2061532231.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   specific_stops.to_sql(name='stops_clean', con=engine, if_exists='replace')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[120], line 3
#       1 specific_stops = pd.read_csv("/Users/tiansuohaoer/Desktop/DATA/Stops.txt", na_values=["np.nan", "np", "NaN"])
#       2 specific_stops = specific_stops[(specific_stops != 0).all(axis=1)]
# ----> 3 specific_stops.to_sql(name='stops_clean', con=engine, if_exists='replace')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
print(engine)

# %%
specific_stops
# Out:
#         stop_id  stop_code                          stop_name   stop_lat  \
# 266      200020        NaN                      Circular Quay -33.861351
# 267      200030        NaN               Martin Place Station -33.867847
# 268     2000321  2000321.0        Central Station, Platform 1 -33.882703
# 269     2000322  2000322.0        Central Station, Platform 2 -33.882751
# 270     2000323  2000323.0        Central Station, Platform 3 -33.882768
# ...         ...        ...                                ...        ...
# 114713   212753   212753.0  Sydney Olympic Park Wharf, Side B -33.822016
# 114714  2137185  2137185.0             Cabarita Wharf, Side A -33.840669
# 114715  2137186  2137186.0             Cabarita Wharf, Side B -33.840769
# 114716    21501    21501.0                   Parramatta Wharf -33.813904
# 114717  2150112        NaN                   Parramatta Wharf -33.813952
#
#           stop_lon  location_type parent_station  wheelchair_boarding  \
# ...

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/bin/python

# %%
print(sqlalchemy.__version__)
# Out:
# 1.4.49
